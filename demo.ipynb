# %% [raw]
# Jim,
# This is a demo of using Jupyter online strictly through your browser,
# no software to install.  This notebook works exactly like a notebook
# open in Jupyter on your computer.  Jupyter is actually running on the
# web server of an outfit name Binder.

# %%
print('We''ll do some math ...\n')
x = int(input('Enter an integer: '))
print('Powers of', x,'from 0 to 10')
for i in range(11):
    print(f'{i:4} {x**i}')

print('\nroots of', x,'from 1 to 10\n')
for i in range(1,11):
    print(f'{i:4} {x**(1/i):12.5f}')

print('\nEnd of demo')
# Out:
# Well do some math ...
#
# Enter an integer: 555
# Powers of 555 from 0 to 10
#    0 1
#    1 555
#    2 308025
#    3 170953875
#    4 94879400625
#    5 52658067346875
#    6 29225227377515625
#    7 16220001194521171875
#    8 9002100662959250390625
#    9 4996165867942383966796875
#   10 2772872056708023101572265625
#
# roots of 555 from 1 to 10
#
#    1    555.00000
#    2     23.55844
#    3      8.21797
#    4      4.85370
#    5      3.53882
#    6      2.86670
#    7      2.46628
#    8      2.20311
#    9      2.01800
#   10      1.88118
#
# End of demo
