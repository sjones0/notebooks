# %%
import time
def fib(n):
#    print(n,end=' ')
    if n == 0:
        return 0
    elif n == 1 or n == 2:
        return 1
    else:
        return fib(n-1) + fib(n-2)

x = int(input('Enter number of terms: '))
t = time.perf_counter()
for i in range(x):
    f = fib(i)
    t2 = time.perf_counter()-t
    print(f'{i:3} {t2:10.5f} {f:10}')
    t = time.perf_counter()
# Out:
# Enter number of terms: 40
#   0    0.00012          0
#   1    0.00000          1
#   2    0.00000          1
#   3    0.00000          2
#   4    0.00000          3
#   5    0.00000          5
#   6    0.00000          8
#   7    0.00001         13
#   8    0.00001         21
#   9    0.00002         34
#  10    0.00003         55
#  11    0.00004         89
#  12    0.00006        144
#  13    0.00010        233
#  14    0.00017        377
#  15    0.00025        610
#  16    0.00040        987
#  17    0.00064       1597
#  18    0.00107       2584
#  19    0.00175       4181
#  20    0.00279       6765
#  21    0.00442      10946
#  22    0.00737      17711
#  23    0.01212      28657
#  24    0.01890      46368
#  25    0.02922      75025
#  26    0.04479     121393
#  27    0.07617     196418
#  28    0.13458     317811
#  29    0.19732     514229
#  30    0.32009     832040
#  31    0.55211    1346269
#  32    0.90604    2178309
#  33    1.44079    3524578
#  34    2.12079    5702887
#  35    3.30537    9227465
#  36    5.31938   14930352
#  37    8.84132   24157817
#  38   14.02828   39088169
#  39   22.81668   63245986
